# %% [markdown]
# # Welcome to Pandas Basics

# %%
print("hello")
# Out:
# hello

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.1

# %% [markdown]
# # Key Data Structures in pandas
# * series (1 Dimensional)
# * Dataframe (2 Dimensional)

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index = ['a', 'b', 'c', 'd', 'e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"names": ["John", "Michael", "Smith"], "marks":[100,57,94]})

# %%
df
# Out:
#      names  marks
# 0     John    100
# 1  Michael     57
# 2    Smith     94

# %%
df = pd.read_csv("data/people-100.csv")

# %%
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          100 non-null    int64
#  1   User Id        100 non-null    object
#  2   First Name     100 non-null    object
#  3   Last Name      100 non-null    object
#  4   Sex            100 non-null    object
#  5   Email          100 non-null    object
#  6   Phone          100 non-null    object
#  7   Date of birth  100 non-null    object
#  8   Job Title      100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %% [markdown]
# # Data Selection

# %%
df["First Name"]
# Out:
# 0       Shelby
# 1      Phillip
# 2     Kristine
# 3      Yesenia
# 4         Lori
#         ...
# 95      Dennis
# 96       Steve
# 97      Wesley
# 98      Summer
# 99      Mariah
# Name: First Name, Length: 100, dtype: object

# %%
type(df["First Name"])
# Out:
# pandas.core.series.Series

# %%
df[["First Name", "Sex"]]
# Out:
#    First Name     Sex
# 0      Shelby    Male
# 1     Phillip  Female
# 2    Kristine    Male
# 3     Yesenia    Male
# 4        Lori    Male
# ..        ...     ...
# 95     Dennis  Female
# 96      Steve  Female
# 97     Wesley    Male
# 98     Summer  Female
# 99     Mariah    Male
#
# [100 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Index                                 1
# User Id                 88F7B33d2bcf9f5
# First Name                       Shelby
# Last Name                       Terrell
# Sex                                Male
# Email              elijah57@example.net
# Phone            001-084-906-7849x73518
# Date of birth                1945-10-26
# Job Title               Games developer
# Name: 0, dtype: object

# %%
df2 = pd.read_csv("data/people-100-indian.csv")

# %%
df2
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2  f90cD3E76f1A9b9     Kartik    Summers  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       4  A31Bee3c201ef58     Ishaan   Martinez    Male
# 4       5  1bA7A3dc874da3c      Nisha       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E        Sai     Barnes  Female
# 96     97  CCbFce93d3720bE      Meera  Patterson  Female
# 97     98  2fEc528aFAF0b69        Sai       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 99    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df2 = pd.read_csv("data/people-100-indian.csv")

# %%
df2
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2  f90cD3E76f1A9b9     Kartik    Summers  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6  bfDD7CDEF5D865B      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1                          NaN       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df2
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2  f90cD3E76f1A9b9     Kartik    Summers  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6  bfDD7CDEF5D865B      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1                          NaN       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df2 = pd.read_csv("data/people-100-indian.csv")

# %%
df2
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2              NaN     Kartik        NaN  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6              NaN      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1                          NaN       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df2.fillna(0)
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2                0     Kartik          0  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c          0       Todd    Male
# 4       6                0      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1                            0       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df2.rename(columns= {"User Id": "User_Id"})
# Out:
#     Index          User_Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2              NaN     Kartik        NaN  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6              NaN      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1                          NaN       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df2.rename(columns={"Date of birth": "DOB", "User Id": "User_Id"}, inplace = True)

# %%
df2
# Out:
#     Index          User_Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2              NaN     Kartik        NaN  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6              NaN      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone         DOB  \
# 0         elijah57@example.net  001-084-906-7849x73518  1945-10-26
# 1                          NaN       214.112.6044x4913  1910-03-24
# 2        bthompson@example.com            277.609.7938  1992-07-02
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Index       98 non-null     int64
#  1   User_Id     96 non-null     object
#  2   First Name  96 non-null     object
#  3   Last Name   97 non-null     object
#  4   Sex         97 non-null     object
#  5   Email       97 non-null     object
#  6   Phone       98 non-null     object
#  7   DOB         98 non-null     object
#  8   Job Title   98 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 7.0+ KB

# %%
df2['User_Id'] = df2['User_Id'].astype(str)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Index       98 non-null     int64
#  1   User_Id     98 non-null     object
#  2   First Name  96 non-null     object
#  3   Last Name   97 non-null     object
#  4   Sex         97 non-null     object
#  5   Email       97 non-null     object
#  6   Phone       98 non-null     object
#  7   DOB         98 non-null     object
#  8   Job Title   98 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 7.0+ KB

# %%
df2["User_Id"][0]
# Out:
# '88F7B33d2bcf9f5'

# %%
len(df)
# Out:
# 100

# %%
df2["Table"] = [i for i in range(1, len(df2)+1)]

# %%
df2
# Out:
#     Index          User_Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2              nan     Kartik        NaN  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6              nan      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone         DOB  \
# 0         elijah57@example.net  001-084-906-7849x73518  1945-10-26
# 1                          NaN       214.112.6044x4913  1910-03-24
# 2        bthompson@example.com            277.609.7938  1992-07-02
# ...

# %%
df2["Table square"] = df2["Table"].apply(lambda x: x * x)

# %%
df2 = df2.drop(columns=["Roll_No"])

# %%
df2
# Out:
#     Index          User_Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2              nan     Kartik        NaN  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6              nan      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone         DOB  \
# 0         elijah57@example.net  001-084-906-7849x73518  1945-10-26
# 1                          NaN       214.112.6044x4913  1910-03-24
# 2        bthompson@example.com            277.609.7938  1992-07-02
# ...

# %%
df2
# Out:
#     Index          User_Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5      Tanvi    Terrell    Male
# 1       2              nan     Kartik        NaN  Female
# 2       3  DbeAb8CcdfeFC2c     Aadhya     Travis    Male
# 3       5  1bA7A3dc874da3c        NaN       Todd    Male
# 4       6              nan      Nisha        Day    Male
# ..    ...              ...        ...        ...     ...
# 93     96  5eFda7caAeB260E        Sai     Barnes  Female
# 94     97  CCbFce93d3720bE      Meera  Patterson  Female
# 95     98  2fEc528aFAF0b69        Sai       Bray    Male
# 96     99  Adc7ad9B6e4A1Fe       Diya   Oconnell  Female
# 97    100  b8D0aD3490FC7e1       Neha    Bernard    Male
#
#                          Email                   Phone         DOB  \
# 0         elijah57@example.net  001-084-906-7849x73518  1945-10-26
# 1                          NaN       214.112.6044x4913  1910-03-24
# 2        bthompson@example.com            277.609.7938  1992-07-02
# ...
